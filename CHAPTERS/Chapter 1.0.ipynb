# %%
#import libraries
from PIL import Image
import numpy as np
import matplotlib.pyplot as pl

# reading image to array
im = np.array(Image.open('empire.jpg'))
print("Shape is: {0} of type {1}".format(im.shape, im.dtype))

#grayscale vversion
im = np.array(Image.open('empire.jpg').convert('L'),'f')
print("Shape is: {0} of type {1}".format(im.shape, im.dtype))

# visualize the pixel value of a small region
col_1, col_2 = 100, 225
row_1, row_2 = 30, 265

# crop using array slicing
crop = im[col_1:col_2,row_1:row_2]
cols, rows = crop.shape

print("Created crop of shape: {0}".format(crop.shape))
# Out:
# Shape is: (365, 300, 3) of type uint8
# Shape is: (365, 300) of type float32
# Created crop of shape: (125, 235)

# %%
# plot image without axis with linewidth to be 4
pl.figure()
pl.imshow(im)
pl.gray()
pl.plot([row_1, row_2, row_2, row_1, row_1], [col_1, col_1, col_2, col_2, col_1], linewidth=4)
pl.axis('off')
pl.show()

# %%
#show portion which was crop
pl.figure()
pl.imshow(crop)
pl.gray()
pl.axis('off')
pl.show()

# %%
pl.figure()
pl.imshow(crop)
pl.gray()
pl.plot(20*np.ones(cols), linewidth=2)
pl.axis('off')
pl.show()

# %%
print(10*np.ones(cols)) 
range(10)
# Out:
# [10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10.
#  10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10.
#  10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10.
#  10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10.
#  10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10.
#  10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10.
#  10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10.]
# range(0, 10)

# %%
pl.figure()
pl.plot(crop[20,:])
pl.ylabel("Graylevel value")
pl.show()

# %%
from PIL import Image
from numpy import *
from scipy.ndimage import measurements
from scipy.ndimage import morphology

"""
This is the morphology counting objects example in Section 1.4.
"""

# load image and threshold to make sure it is binary
im = array(Image.open('empire.jpg').convert('L'))
pl.figure();
pl.imshow(im)
pl.show()

# %%
#applying morphology to image
im = (im<128)
pl.figure();
pl.imshow(im)
pl.show();

labels, nbr_objects = measurements.label(im)
print("Number of objects:", nbr_objects)

# morphology - opening to separate objects better
im_open = morphology.binary_opening(im,ones((9,5)),iterations=2) 

labels_open, nbr_objects_open = measurements.label(im_open)
print("Number of objects:", nbr_objects_open)
# Out:
# Number of objects: 193
# Number of objects: 9
